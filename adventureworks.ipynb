# %% [markdown]
# # Exercise 2

# %%
import pandas as pd
import numpy as np

# %%
sales_df = pd.read_excel("AdventureWorks Sales.xlsx", sheet_name="Sales_data", header=0)
sales_df.head()
# Out:
#    SalesOrderLineKey  ResellerKey  CustomerKey  ProductKey  OrderDateKey  \
# 0           43659001          676           -1         349      20170702
# 1           43659002          676           -1         350      20170702
# 2           43659003          676           -1         351      20170702
# 3           43659004          676           -1         344      20170702
# 4           43659005          676           -1         345      20170702
#
#    DueDateKey  ShipDateKey  SalesTerritoryKey  Order Quantity  Unit Price  \
# 0    20170712   20170709.0                  5               1    2024.994
# 1    20170712   20170709.0                  5               3    2024.994
# 2    20170712   20170709.0                  5               1    2024.994
# 3    20170712   20170709.0                  5               1    2039.994
# 4    20170712   20170709.0                  5               1    2039.994
#
#    Extended Amount  Unit Price Discount Pct  Product Standard Cost  \
# ...

# %%
reseller_df = pd.read_excel("AdventureWorks Sales.xlsx", sheet_name="Reseller_data", header=0)
reseller_df.head()
# Out:
#    ResellerKey       Reseller ID         Business Type  \
# 0           -1  [Not Applicable]      [Not Applicable]
# 1            1        AW00000001  Value Added Reseller
# 2            2        AW00000002   Specialty Bike Shop
# 3            3        AW00000003             Warehouse
# 4            4        AW00000004  Value Added Reseller
#
#                    Reseller              City    State-Province  \
# 0          [Not Applicable]  [Not Applicable]  [Not Applicable]
# 1              A Bike Store           Seattle        Washington
# 2        Progressive Sports            Renton        Washington
# 3  Advanced Bike Components            Irving             Texas
# 4     Modular Cycle Systems            Austin             Texas
#
#      Country-Region       Postal Code
# 0  [Not Applicable]  [Not Applicable]
# 1     United States             98104
# 2     United States             98055
# 3     United States             75061
# 4     United States             78701

# %%
date_df = pd.read_excel("AdventureWorks Sales.xlsx", sheet_name="Date_data", header=0)
date_df.head()
# Out:
#     DateKey       Date Fiscal Year Fiscal Quarter     Month     Full Date  \
# 0  20170701 2017-07-01      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 01
# 1  20170702 2017-07-02      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 02
# 2  20170703 2017-07-03      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 03
# 3  20170704 2017-07-04      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 04
# 4  20170705 2017-07-05      FY2018      FY2018 Q1  2017 Jul  2017 Jul, 05
#
#    MonthKey
# 0    201707
# 1    201707
# 2    201707
# 3    201707
# 4    201707

# %%
product_df = pd.read_excel("AdventureWorks Sales.xlsx", sheet_name="Product_data", header=0)
product_df.head()
# Out:
#    ProductKey         SKU                    Product  Standard Cost  Color  \
# 0         210  FR-R92B-58  HL Road Frame - Black, 58       868.6342  Black
# 1         211  FR-R92R-58    HL Road Frame - Red, 58       868.6342    Red
# 2         212   HL-U509-R      Sport-100 Helmet, Red        12.0278    Red
# 3         213   HL-U509-R      Sport-100 Helmet, Red        13.8782    Red
# 4         214   HL-U509-R      Sport-100 Helmet, Red        13.0863    Red
#
#    List Price          Model  Subcategory     Category
# 0   1431.5000  HL Road Frame  Road Frames   Components
# 1   1431.5000  HL Road Frame  Road Frames   Components
# 2     33.6442      Sport-100      Helmets  Accessories
# 3     33.6442      Sport-100      Helmets  Accessories
# 4     34.9900      Sport-100      Helmets  Accessories

# %%
customer_df = pd.read_excel("AdventureWorks Sales.xlsx", sheet_name="Customer_data", header=0)
customer_df.head()
# Out:
#    CustomerKey       Customer ID          Customer              City  \
# 0           -1  [Not Applicable]  [Not Applicable]  [Not Applicable]
# 1        11000        AW00011000          Jon Yang       Rockhampton
# 2        11001        AW00011001      Eugene Huang           Seaford
# 3        11002        AW00011002      Ruben Torres            Hobart
# 4        11003        AW00011003       Christy Zhu        North Ryde
#
#      State-Province    Country-Region       Postal Code
# 0  [Not Applicable]  [Not Applicable]  [Not Applicable]
# 1        Queensland         Australia              4700
# 2          Victoria         Australia              3198
# 3          Tasmania         Australia              7001
# 4   New South Wales         Australia              2113

# %% [markdown]
# ## Part 1

# %% [markdown]
# **1. What is the role of each table in the sales process?**
